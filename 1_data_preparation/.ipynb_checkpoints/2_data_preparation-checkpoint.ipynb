# %%
#!pip install dask
#!pip install dask-expr
import dask.dataframe as dd
import pandas as pd
import dask
import re

# %%
# Use dask to import the data because the raw data is too large to process by pandas (3.6GB)
# Upload chunk by chunk
df = dd.read_csv(
    "../0_data/all_reviews_cleaned.csv",
    dtype=str,
    blocksize="64MB"
)
len(df)
# Out:
# 8098892

# %%
# Data wrangling
# Clean column names (lowercase and underscore)
df.columns = df.columns.str.lower().str.strip().str.replace(" ", "_").str.replace("/", "_").str.replace("&", "and")

# Modify v / x / o columns
vx_cols = ["recommend", "ceo_approval", "business_outlook"]

vx_map = {"v": 1, "x": -1, "o": 0}

for col in vx_cols:
    if col in df.columns:
        df[col] = df[col].str.strip().str.lower()
        df[col] = df[col].map(vx_map).astype("float32")

# Convert numeric rating columns
numeric_cols = [
    "rating",
    "career_opportunities",
    "compensation_and_benefits",
    "senior_management",
    "work_life_balance",
    "culture_and_values",
    "diversity_and_inclusion"
]

for col in numeric_cols:
    if col in df.columns:
        df[col] = dd.to_numeric(df[col], errors="coerce")
        df[col] = df[col].where(df[col].between(1, 5))

# Clean NAs
df = df.replace({"<NA>": None})

# Parse dates
if "date" in df.columns:
    df["date"] = dd.to_datetime(df["date"], errors="coerce")

# Preview
df.head()
# Out:
# /Users/norazhan/Library/Python/3.9/lib/python/site-packages/dask_expr/_collection.py:4190: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('recommend', 'float64'))
#
#   warnings.warn(meta_warning(meta))
# /Users/norazhan/Library/Python/3.9/lib/python/site-packages/dask_expr/_collection.py:4190: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('ceo_approval', 'float64'))
#
#   warnings.warn(meta_warning(meta))
# /Users/norazhan/Library/Python/3.9/lib/python/site-packages/dask_expr/_collection.py:4190: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('business_outlook', 'float64'))
#
#   warnings.warn(meta_warning(meta))
#    rating                              title  \
# 0     5.0                               Good
# 1     4.0                               Good
# 2     1.0                           terrible
# 3     4.0  It could be so good, but it isn’t
# 4     3.0                        Good enough
#
#                                  status  \
# 0  Current Employee, more than 10 years
# 1     Former Employee, less than 1 year
# 2    Current Employee, more than 1 year
# 3   Current Employee, more than 3 years
# 4    Former Employee, more than 5 years
#
#                                                 pros  \
# 0                Knowledge gain of complete  project
# 1            Good work,good work , flexible, support
# 2                     I wish there were some to list
# 3  Fast Paced. Endless challenges. Inclusive envi...
# 4            Discounts, benefits, life long friends.
#
#                                                 cons advice  recommend  \
# 0              Financial growth  and personal growth    NaN        1.0
# 1   Good,work, flexible,good support, good team work    NaN        1.0
# 2                              too many to list here    NaN       -1.0
# 3  The biggest perk of the job provides no value ...    NaN        0.0
# 4                  Drama, playing favorites, low pay    NaN       -1.0
#
#    ceo_approval  business_outlook  career_opportunities  \
# 0           0.0               1.0                   3.0
# 1           0.0               0.0                   4.0
# 2          -1.0              -1.0                   1.0
# 3           0.0               0.0                   3.0
# 4           NaN               NaN                   2.0
#
#    compensation_and_benefits  senior_management  work_life_balance  \
# 0                        3.0                3.0                3.0
# 1                        4.0                4.0                4.0
# 2                        3.0                1.0                3.0
# 3                        3.0                3.0                1.0
# 4                        2.0                2.0                2.0
#
#    culture_and_values  diversity_and_inclusion  \
# 0                 3.0                      3.0
# 1                 4.0                      4.0
# 2                 1.0                      NaN
# 3                 4.0                      5.0
# 4                 2.0                      2.0
#
#                                            firm_link       date  \
# 0  Reviews/Baja-Steel-and-Fence-Reviews-E5462645.htm 2022-11-19
# 1  Reviews/Baja-Steel-and-Fence-Reviews-E5462645.htm 2022-01-29
# 2  https://www.glassdoor.com/Reviews/Calgary-Flam... 2020-09-24
# 3  https://www.glassdoor.com/Reviews/Calgary-Flam... 2023-03-25
# 4  https://www.glassdoor.com/Reviews/Calgary-Flam... 2023-04-06
#
#                         job index
# 0            Manager Design   NaN
# 1        Anonymous Employee   NaN
# 2  Senior Account Executive   NaN
# 3         Assistant Manager   NaN
# 4          Floor Supervisor   NaN

# %%
# Check how many NAs are in the dataset
df.isna().sum().compute()
# Out:
# rating                         15561
# title                          36685
# status                           186
# pros                             193
# cons                             213
# advice                       8098797
# recommend                        258
# ceo_approval                 1479833
# business_outlook             1311340
# career_opportunities         1714873
# compensation_and_benefits    1771585
# senior_management            1812614
# work_life_balance            1773940
# culture_and_values           1958037
# diversity_and_inclusion      5353555
# firm_link                          0
# date                          516716
# job                           571142
# index                        7961347
# dtype: int64

# %%
# Since there are too many NAs for columns recommend and index, we exclude them from later analysis
df = df.drop(columns=["advice", "index"])
df.head()
# Out:
#    rating                              title  \
# 0     5.0                               Good
# 1     4.0                               Good
# 2     1.0                           terrible
# 3     4.0  It could be so good, but it isn’t
# 4     3.0                        Good enough
#
#                                  status  \
# 0  Current Employee, more than 10 years
# 1     Former Employee, less than 1 year
# 2    Current Employee, more than 1 year
# 3   Current Employee, more than 3 years
# 4    Former Employee, more than 5 years
#
#                                                 pros  \
# 0                Knowledge gain of complete  project
# 1            Good work,good work , flexible, support
# 2                     I wish there were some to list
# 3  Fast Paced. Endless challenges. Inclusive envi...
# 4            Discounts, benefits, life long friends.
#
#                                                 cons  recommend  ceo_approval  \
# 0              Financial growth  and personal growth        1.0           0.0
# 1   Good,work, flexible,good support, good team work        1.0           0.0
# 2                              too many to list here       -1.0          -1.0
# 3  The biggest perk of the job provides no value ...        0.0           0.0
# 4                  Drama, playing favorites, low pay       -1.0           NaN
#
#    business_outlook  career_opportunities  compensation_and_benefits  \
# 0               1.0                   3.0                        3.0
# 1               0.0                   4.0                        4.0
# 2              -1.0                   1.0                        3.0
# 3               0.0                   3.0                        3.0
# 4               NaN                   2.0                        2.0
#
#    senior_management  work_life_balance  culture_and_values  \
# 0                3.0                3.0                 3.0
# 1                4.0                4.0                 4.0
# 2                1.0                3.0                 1.0
# 3                3.0                1.0                 4.0
# 4                2.0                2.0                 2.0
#
#    diversity_and_inclusion                                          firm_link  \
# 0                      3.0  Reviews/Baja-Steel-and-Fence-Reviews-E5462645.htm
# 1                      4.0  Reviews/Baja-Steel-and-Fence-Reviews-E5462645.htm
# 2                      NaN  https://www.glassdoor.com/Reviews/Calgary-Flam...
# 3                      5.0  https://www.glassdoor.com/Reviews/Calgary-Flam...
# 4                      2.0  https://www.glassdoor.com/Reviews/Calgary-Flam...
#
#         date                       job
# 0 2022-11-19            Manager Design
# 1 2022-01-29        Anonymous Employee
# 2 2020-09-24  Senior Account Executive
# 3 2023-03-25         Assistant Manager
# 4 2023-04-06          Floor Supervisor

# %%
# Notice there is a <NA> in the column "diversity_and_inclusion", make sure the <NA> is real NA, not a string
(df["diversity_and_inclusion"] == "<NA>").any().compute()
# Out:
# False

# %%
# The result is False, so we can proceed with our data preparation even though there are different representations of NA values in the dataset

# %%
# Create a list of target companies and manually get firm IDs from Glassdoor
target_companies = {
    # Healthcare
    "HCA Healthcare": "E2062",
    "Ascension": "E1036988",
    "CommonSpirit Health": "E2611593",
    "Trinity Health": "E2896",
    "Community Health Systems": "E1548",
    "Tenet Healthcare": "E466",
    "AdventHealth": "E17651",
    "Providence": "E4651",
    "Mayo Clinic": "E19884",
    "Cleveland Clinic": "E17787",
    "U.S. Department of Veterans Affairs": "E41429",
    "NewYork-Presbyterian Hospital": "E121522",
    "Mass General Brigham": "E6284",
    "Geisinger Health System": "E12935",
    "Intermountain Health": "E2842",

    # Telecom, Transportation, Energy
    "AT&T": "E613",
    "Comcast": "E1280",
    "Union Pacific": "E691",
    "CSX": "E124",
    "American Tower": "E8043",
    "Norfolk Southern": "E483",
    "Kinder Morgan": "E4156",
    "Sempra": "E8437",
    "Plains All American Pipeline": "E8858",
    "Crown Castle": "E8416",
    "SBA Communications": "E9253",
    "Uniti Group": "E7953615",
    # "Construction Partners" has no Glassdoor profile
    "Par Pacific Holdings": "E1460669",
    "Radius Global": "E1088779"
}

# %%
# Extract firm IDs from the firm_link variable, use these to match target companies
df["firm_id"] = df["firm_link"].str.extract(r"(E\d+)", expand=False)
df["firm_id"].dropna().head(10)
# Out:
# 0    E5462645
# 1    E5462645
# 2       E5247
# 3       E5247
# 4       E5247
# 5       E5247
# 6       E5247
# 7       E5247
# 8       E5247
# 9       E5247
# Name: firm_id, dtype: object

# %%
# Compute how many reviews are matched for each company
firm_counts = df["firm_id"].value_counts().compute()
print(firm_counts)
# Out:
# firm_id
# E10030      185
# E1011        26
# E10194       14
# E1020428     13
# E1028653     19
#            ...
# E9781         2
# E9844         9
# E9881        33
# E9904        58
# E9978        11
# Name: count, Length: 34292, dtype: int64

# %%
results = {name: firm_counts.get(eid, 0) for name, eid in target_companies.items()}
print(results)
# Out:
# {'HCA Healthcare': 5326, 'Ascension': 0, 'CommonSpirit Health': 0, 'Trinity Health': 0, 'Community Health Systems': 1138, 'Tenet Healthcare': 1167, 'AdventHealth': 0, 'Providence': 0, 'Mayo Clinic': 5274, 'Cleveland Clinic': 3467, 'U.S. Department of Veterans Affairs': 0, 'NewYork-Presbyterian Hospital': 2543, 'Mass General Brigham': 844, 'Geisinger Health System': 0, 'Intermountain Health': 1907, 'AT&T': 0, 'Comcast': 12401, 'Union Pacific': 2235, 'CSX': 1099, 'American Tower': 557, 'Norfolk Southern': 1327, 'Kinder Morgan': 716, 'Sempra': 169, 'Plains All American Pipeline': 227, 'Crown Castle': 636, 'SBA Communications': 377, 'Uniti Group': 0, 'Par Pacific Holdings': 0, 'Radius Global': 0}

# %%
# Get IDs of the companies that have matched reviews
matching_eids = [eid for eid in target_companies.values() if firm_counts.get(eid, 0) > 0]
print(matching_eids)
# Out:
# ['E2062', 'E1548', 'E466', 'E19884', 'E17787', 'E121522', 'E6284', 'E2842', 'E1280', 'E691', 'E124', 'E8043', 'E483', 'E4156', 'E8437', 'E8858', 'E8416', 'E9253']

# %%
# Filter the dataset to only contain reviews of matched companies
# This will take some time to run
filtered_df = df[df["firm_id"].isin(matching_eids)]
pdf = filtered_df.compute()
pdf.head()
# Out:
#        rating                                         title  \
# 18596     5.0  Administrative Assistant/Prior Authorization
# 18597     4.0                                 Great Company
# 18598     5.0                                             .
# 18599     5.0                     Annual performance review
# 18600     2.0                             Quality Comes 2nd
#
#                                      status  \
# 18596    Current Employee, more than 1 year
# 18597  Current Employee, more than 10 years
# 18598    Current Employee, less than 1 year
# 18599                       Former Employee
# 18600   Current Employee, more than 3 years
#
#                                                     pros  \
# 18596  Great Staff to work with, Encourages Team and ...
# 18597  I have been with CHS for quite some time now. ...
# 18598      Pretty remarkable, Loved the work-life event.
# 18599   Medicare annual wellness visits free for seniors
# 18600  Great benefits and great teamwork on the front...
#
#                                                     cons  recommend  \
# 18596  Pay needs to increase along with the work you'...        0.0
# 18597  The pay has mostly stayed the same with the in...        1.0
# 18598  Commute was all right. Didn't find the locatio...        1.0
# 18599     Communication to its employees more frequently        1.0
# 18600  Patients are accepted even when we do not have...       -1.0
#
#        ceo_approval  business_outlook  career_opportunities  \
# 18596           0.0               0.0                   NaN
# 18597           1.0               NaN                   5.0
# 18598           1.0               1.0                   5.0
# 18599           0.0               1.0                   5.0
# 18600           NaN               NaN                   2.0
#
#        compensation_and_benefits  senior_management  work_life_balance  \
# 18596                        NaN                NaN                NaN
# 18597                        4.0                5.0                5.0
# 18598                        5.0                5.0                5.0
# 18599                        5.0                3.0                3.0
# 18600                        4.0                2.0                2.0
#
#        culture_and_values  diversity_and_inclusion  \
# 18596                 NaN                      NaN
# 18597                 5.0                      5.0
# 18598                 5.0                      5.0
# 18599                 5.0                      5.0
# 18600                 1.0                      3.0
#
#                                                firm_link       date  \
# 18596  Reviews/Community-Health-Systems-Reviews-E1548... 2022-11-12
# 18597  Reviews/Community-Health-Systems-Reviews-E1548... 2023-01-29
# 18598  Reviews/Community-Health-Systems-Reviews-E1548... 2023-04-06
# 18599  Reviews/Community-Health-Systems-Reviews-E1548... 2023-04-04
# 18600  Reviews/Community-Health-Systems-Reviews-E1548... 2023-03-26
#
#                                          job firm_id
# 18596               Administrative Assistant   E1548
# 18597                             Supervisor   E1548
# 18598                               Engineer   E1548
# 18599  Customer Service Representative (CSR)   E1548
# 18600                  Registered Nurse, BSN   E1548

# %%
# Make NA values all pandas extension types
pdf = pdf.convert_dtypes()
pdf.head()
# Out:
#        rating                                         title  \
# 18596       5  Administrative Assistant/Prior Authorization
# 18597       4                                 Great Company
# 18598       5                                             .
# 18599       5                     Annual performance review
# 18600       2                             Quality Comes 2nd
#
#                                      status  \
# 18596    Current Employee, more than 1 year
# 18597  Current Employee, more than 10 years
# 18598    Current Employee, less than 1 year
# 18599                       Former Employee
# 18600   Current Employee, more than 3 years
#
#                                                     pros  \
# 18596  Great Staff to work with, Encourages Team and ...
# 18597  I have been with CHS for quite some time now. ...
# 18598      Pretty remarkable, Loved the work-life event.
# 18599   Medicare annual wellness visits free for seniors
# 18600  Great benefits and great teamwork on the front...
#
#                                                     cons  recommend  \
# 18596  Pay needs to increase along with the work you'...          0
# 18597  The pay has mostly stayed the same with the in...          1
# 18598  Commute was all right. Didn't find the locatio...          1
# 18599     Communication to its employees more frequently          1
# 18600  Patients are accepted even when we do not have...         -1
#
#        ceo_approval  business_outlook  career_opportunities  \
# 18596             0                 0                  <NA>
# 18597             1              <NA>                     5
# 18598             1                 1                     5
# 18599             0                 1                     5
# 18600          <NA>              <NA>                     2
#
#        compensation_and_benefits  senior_management  work_life_balance  \
# 18596                       <NA>               <NA>               <NA>
# 18597                          4                  5                  5
# 18598                          5                  5                  5
# 18599                          5                  3                  3
# 18600                          4                  2                  2
#
#        culture_and_values  diversity_and_inclusion  \
# 18596                <NA>                     <NA>
# 18597                   5                        5
# 18598                   5                        5
# 18599                   5                        5
# 18600                   1                        3
#
#                                                firm_link       date  \
# 18596  Reviews/Community-Health-Systems-Reviews-E1548... 2022-11-12
# 18597  Reviews/Community-Health-Systems-Reviews-E1548... 2023-01-29
# 18598  Reviews/Community-Health-Systems-Reviews-E1548... 2023-04-06
# 18599  Reviews/Community-Health-Systems-Reviews-E1548... 2023-04-04
# 18600  Reviews/Community-Health-Systems-Reviews-E1548... 2023-03-26
#
#                                          job firm_id
# 18596               Administrative Assistant   E1548
# 18597                             Supervisor   E1548
# 18598                               Engineer   E1548
# 18599  Customer Service Representative (CSR)   E1548
# 18600                  Registered Nurse, BSN   E1548

# %%
# We have 41410 matched reviews in total
pdf.shape
# Out:
# (41410, 18)

# %%
# Check if the companies are correct
unique_ids = pdf["firm_id"].unique()
print(unique_ids)
# Out:
# <StringArray>
# [  'E1548',   'E9253',   'E2062',   'E6284',    'E124',    'E466',    'E691',
#     'E483',   'E8858',  'E19884', 'E121522',   'E1280',  'E17787',   'E8043',
#    'E4156',   'E8416',   'E2842',   'E8437']
# Length: 18, dtype: string

# %%
unique_links = pdf["firm_link"].unique()
print(unique_links)
# Out:
# <StringArray>
# [                                      'Reviews/Community-Health-Systems-Reviews-E1548.htm',
#                    'https://www.glassdoor.com/Reviews/SBA-Communications-Reviews-E9253.htm',
#                                                  'Reviews/HCA-Healthcare-Reviews-E2062.htm',
#                  'https://www.glassdoor.com/Reviews/Mass-General-Brigham-Reviews-E6284.htm',
#                                                              'Reviews/CSX-Reviews-E124.htm',
#                                                 'Reviews/Tenet-Healthcare-Reviews-E466.htm',
#                                                    'Reviews/Union-Pacific-Reviews-E691.htm',
#                                                 'Reviews/Norfolk-Southern-Reviews-E483.htm',
#          'https://www.glassdoor.com/Reviews/Plains-All-American-Pipeline-Reviews-E8858.htm',
#                          'https://www.glassdoor.com/Reviews/Mayo-Clinic-Reviews-E19884.htm',
#       'https://www.glassdoor.com/Reviews/NewYork-Presbyterian-Hospital-Reviews-E121522.htm',
#                                                         'Reviews/Comcast-Reviews-E1280.htm',
#  'https://www.glassdoor.com/Reviews/Comcast-Reviews-E1280_P909.htm?filter.iso3Language=eng',
#                     'https://www.glassdoor.com/Reviews/Cleveland-Clinic-Reviews-E17787.htm',
#                        'https://www.glassdoor.com/Reviews/American-Tower-Reviews-E8043.htm',
#                         'https://www.glassdoor.com/Reviews/Kinder-Morgan-Reviews-E4156.htm',
#                          'https://www.glassdoor.com/Reviews/Crown-Castle-Reviews-E8416.htm',
#                  'https://www.glassdoor.com/Reviews/Intermountain-Health-Reviews-E2842.htm',
#                                'https://www.glassdoor.com/Reviews/Sempra-Reviews-E8437.htm']
# Length: 19, dtype: string

# %%
# There seems to be more firm_links than expected (19 instead of 18)
# Map firm_link with firm_id to see what happened
mapping = pdf.groupby("firm_id")["firm_link"].unique()

for fid, links in mapping.items():
    print(fid)
    for link in links:
        print(link)
# Out:
# E121522
# https://www.glassdoor.com/Reviews/NewYork-Presbyterian-Hospital-Reviews-E121522.htm
# E124
# Reviews/CSX-Reviews-E124.htm
# E1280
# Reviews/Comcast-Reviews-E1280.htm
# https://www.glassdoor.com/Reviews/Comcast-Reviews-E1280_P909.htm?filter.iso3Language=eng
# E1548
# Reviews/Community-Health-Systems-Reviews-E1548.htm
# E17787
# https://www.glassdoor.com/Reviews/Cleveland-Clinic-Reviews-E17787.htm
# E19884
# https://www.glassdoor.com/Reviews/Mayo-Clinic-Reviews-E19884.htm
# E2062
# Reviews/HCA-Healthcare-Reviews-E2062.htm
# E2842
# https://www.glassdoor.com/Reviews/Intermountain-Health-Reviews-E2842.htm
# E4156
# https://www.glassdoor.com/Reviews/Kinder-Morgan-Reviews-E4156.htm
# E466
# Reviews/Tenet-Healthcare-Reviews-E466.htm
# E483
# Reviews/Norfolk-Southern-Reviews-E483.htm
# E6284
# https://www.glassdoor.com/Reviews/Mass-General-Brigham-Reviews-E6284.htm
# E691
# Reviews/Union-Pacific-Reviews-E691.htm
# E8043
# https://www.glassdoor.com/Reviews/American-Tower-Reviews-E8043.htm
# E8416
# https://www.glassdoor.com/Reviews/Crown-Castle-Reviews-E8416.htm
# E8437
# https://www.glassdoor.com/Reviews/Sempra-Reviews-E8437.htm
# E8858
# https://www.glassdoor.com/Reviews/Plains-All-American-Pipeline-Reviews-E8858.htm
# E9253
# https://www.glassdoor.com/Reviews/SBA-Communications-Reviews-E9253.htm

# %%
# For Comcast, there is more than one valid firm link
# To proceed with our data preparation, we will use firm_id to ensure precise matching

# %%
# Define firm groups (all 29 firms)
healthcare_firms = {
    "HCA Healthcare", "Ascension", "CommonSpirit Health", "Trinity Health", "Community Health Systems",
    "Tenet Healthcare", "AdventHealth", "Providence", "Mayo Clinic", "Cleveland Clinic", "U.S. Department of Veterans Affairs",
    "NewYork-Presbyterian Hospital", "Mass General Brigham", "Geisinger Health System", "Intermountain Health",
}


infrastructure_firms = {
    "AT&T", "Comcast", "Union Pacific", "CSX", "American Tower",
    "Norfolk Southern", "Kinder Morgan", "Sempra", "Plains All American Pipeline", "Crown Castle",
    "SBA Communications", "Uniti Group", "Par Pacific Holdings", "Radius Global"
}


# Map company names to firm_ids based on industry
healthcare_eids = [target_companies[name] for name in healthcare_firms]
infra_eids = [target_companies[name] for name in infrastructure_firms]

# Split the dataframe into two based on matched firm_ids
healthcare_df = pdf[pdf["firm_id"].isin(healthcare_eids)]
infrastructure_df = pdf[pdf["firm_id"].isin(infra_eids)]

# Show shapes
print(healthcare_df.shape, infrastructure_df.shape)
# Out:
# (21666, 18) (19744, 18)

# %%
# Save the two split dataframes, proceed with analysis using files in 2_data_analysis folder
healthcare_df.to_csv("../0_data/healthcare_reviews.csv", index=False)
infrastructure_df.to_csv("../0_data/infrastructure_reviews.csv", index=False)
